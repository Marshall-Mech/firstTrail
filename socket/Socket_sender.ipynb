# %%
import numpy as np
import cv2
import random
import time
import socket

img = cv2.imread('image.jpg')

'''cv2.imshow('VICE',img[::2,::2])
cv2.waitKey(0)
cv2.destroyAllWindows()'''
# Out:
# "cv2.imshow('VICE',img[::2,::2])\ncv2.waitKey(0)\ncv2.destroyAllWindows()"

# %%
soc = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
soc.bind((socket.gethostname(),1234))
soc.listen(5)

# %%
while True:
    clientsocket, address = soc.accept()
    print(f'Connected to {address}!')
    r = random.randint(1,1000)
    print(r)  
    clientsocket.send(bytes(str(r),"utf-8"))
    clientsocket.close()
# Out:
# Connected to ('192.168.56.1', 57431)!
# 252
# Connected to ('192.168.56.1', 57470)!
# 96
# Connected to ('192.168.56.1', 57471)!
# 626
# Connected to ('192.168.56.1', 57472)!
# 381
# Connected to ('192.168.56.1', 57473)!
# 21
# Connected to ('192.168.56.1', 57484)!
# 133
# Connected to ('192.168.56.1', 57485)!
# 161
# Connected to ('192.168.56.1', 57486)!
# 456
# Connected to ('192.168.56.1', 57487)!
# 35
# Connected to ('192.168.56.1', 57488)!
# 693
# Connected to ('192.168.56.1', 57492)!
# 115
# Connected to ('192.168.56.1', 57493)!
# 335
# Connected to ('192.168.56.1', 57494)!
# 160
# Connected to ('192.168.56.1', 57495)!
# 530
# Connected to ('192.168.56.1', 57496)!
# 105
# Connected to ('192.168.56.1', 57498)!
# 258
# Connected to ('192.168.56.1', 57499)!
# 730
# Connected to ('192.168.56.1', 57500)!
# 474
# Connected to ('192.168.56.1', 57501)!
# 10
# Connected to ('192.168.56.1', 57502)!
# 733
# Connected to ('192.168.56.1', 57506)!
# 532
# Connected to ('192.168.56.1', 57507)!
# 802
# Connected to ('192.168.56.1', 57508)!
# 944
# Connected to ('192.168.56.1', 57509)!
# 511
# Connected to ('192.168.56.1', 57510)!
# 217
# Connected to ('192.168.56.1', 57512)!
# 52
# Connected to ('192.168.56.1', 57513)!
# 731
# Connected to ('192.168.56.1', 57514)!
# 655
# Connected to ('192.168.56.1', 57515)!
# 453
# Connected to ('192.168.56.1', 57516)!
# 411
# Connected to ('192.168.56.1', 57521)!
# 601
# Connected to ('192.168.56.1', 57522)!
# 92
# Connected to ('192.168.56.1', 57523)!
# 389
# Connected to ('192.168.56.1', 57524)!
# 110
# Connected to ('192.168.56.1', 57525)!
# 806
# Connected to ('192.168.56.1', 57530)!
# 883
# Connected to ('192.168.56.1', 57531)!
# 229
# Connected to ('192.168.56.1', 57532)!
# 118
# Connected to ('192.168.56.1', 57533)!
# 551
# Connected to ('192.168.56.1', 57534)!
# 429
# Connected to ('192.168.56.1', 57537)!
# 815
# Connected to ('192.168.56.1', 57538)!
# 209
# Connected to ('192.168.56.1', 57539)!
# 491
# Connected to ('192.168.56.1', 57540)!
# 565
# Connected to ('192.168.56.1', 57541)!
# 944
# Connected to ('192.168.56.1', 57547)!
# 628
# Connected to ('192.168.56.1', 57548)!
# 851
# Connected to ('192.168.56.1', 57549)!
# 989
# Connected to ('192.168.56.1', 57550)!
# 901
# Connected to ('192.168.56.1', 57551)!
# 351
# Connected to ('192.168.56.1', 57553)!
# 886
# Connected to ('192.168.56.1', 57554)!
# 902
# Connected to ('192.168.56.1', 57555)!
# 658
# Connected to ('192.168.56.1', 57556)!
# 201
# Connected to ('192.168.56.1', 57557)!
# 41
# Connected to ('192.168.56.1', 57562)!
# 27
# Connected to ('192.168.56.1', 57563)!
# 478
# Connected to ('192.168.56.1', 57564)!
# 218
# Connected to ('192.168.56.1', 57565)!
# 307
# Connected to ('192.168.56.1', 57566)!
# 742
# Connected to ('192.168.56.1', 57569)!
# 930
# Connected to ('192.168.56.1', 57570)!
# 739
# Connected to ('192.168.56.1', 57571)!
# 125
# Connected to ('192.168.56.1', 57572)!
# 823
# Connected to ('192.168.56.1', 57573)!
# 86
# Connected to ('192.168.56.1', 57576)!
# 762
# Connected to ('192.168.56.1', 57577)!
# 845
# Connected to ('192.168.56.1', 57578)!
# 871
# Connected to ('192.168.56.1', 57579)!
# 57
# Connected to ('192.168.56.1', 57580)!
# 286
# Connected to ('192.168.56.1', 57585)!
# 331
# Connected to ('192.168.56.1', 57586)!
# 429
# Connected to ('192.168.56.1', 57587)!
# 123
# Connected to ('192.168.56.1', 57588)!
# 1000
# Connected to ('192.168.56.1', 57589)!
# 37
# Connected to ('192.168.56.1', 57594)!
# 912
# Connected to ('192.168.56.1', 57595)!
# 597
# Connected to ('192.168.56.1', 57596)!
# 552
# Connected to ('192.168.56.1', 57597)!
# 637
# Connected to ('192.168.56.1', 57598)!
# 9
